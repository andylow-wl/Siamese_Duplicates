# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytesseract
# !sudo apt install tesseract-ocr
# Out:
# ...
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# The following additional packages will be installed:
#   tesseract-ocr-eng tesseract-ocr-osd
# The following NEW packages will be installed:
#   tesseract-ocr tesseract-ocr-eng tesseract-ocr-osd
# 0 upgraded, 3 newly installed, 0 to remove and 9 not upgraded.
# Need to get 4,816 kB of archives.
# After this operation, 15.6 MB of additional disk space will be used.
# Get:1 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-eng all 1:4.00~git30-7274cfa-1.1 [1,591 kB]
# Get:2 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr-osd all 1:4.00~git30-7274cfa-1.1 [2,990 kB]
# Get:3 http://archive.ubuntu.com/ubuntu jammy/universe amd64 tesseract-ocr amd64 4.1.1-2.1build1 [236 kB]
# Fetched 4,816 kB in 1s (4,232 kB/s)
# debconf: unable to initialize frontend: Dialog
# ...

# %%
# Insert your own project dir
# %cd '/content/drive/MyDrive/Project'

# %%
from PIL import Image, ImageDraw, ImageFilter
import matplotlib.pyplot as plt
import numpy as np
import random
import pandas as pd
import cv2
import os, os.path
import random
import re
import cv2
import pytesseract
from pytesseract import Output
import IPython.display as display
import torchvision.transforms as transforms
import transformation_utils as transform
import torchvision
import torch
from pylab import *

# %%
# Specify the path to the uploaded image in Colab (insert your own project dir)
image_path = '/content/drive/MyDrive/Project/data/train/forms/0000989556.tiff'
# Load the image
image = Image.open(image_path).convert('L')
display.display(image)
# Out:
# <PIL.Image.Image image mode=L size=762x1000>

# %%
noise_image = transform.add_speckle_noise(image)
display.display(noise_image)
# Out:
# <PIL.Image.Image image mode=L size=762x1000>

# %%
zoom_image = transform.random_zoom(image)
display.display(zoom_image)
# Out:
# <PIL.Image.Image image mode=L size=762x1000>

# %%
occluded_image = transform.random_occlusion_with_blur(image,occlusion_size=(100, 100), blur_radius=10)
display.display(occluded_image)
# Out:
# <PIL.Image.Image image mode=L size=762x1000>

# %%
rotated_image = transform.random_rotation_translation(image)
display.display(rotated_image)
# Out:
# <PIL.Image.Image image mode=L size=762x1000>

# %%
copyMove_image = transform.copy_move(image)
display.display(copyMove_image)
# Out:
# <PIL.Image.Image image mode=L size=762x1000>
